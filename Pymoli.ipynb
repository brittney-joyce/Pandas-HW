# %%
import pandas as pd
import random
import numpy as np

# %%
gaming_data = "Jupyter_Notebook/purchase_data.json"

# %%
gaming_data_df = pd.read_json('purchase_data.json')
gaming_data_df.head()
# Out:
#    Age Gender  Item ID                                  Item Name  Price  \
# 0   38   Male      165                Bone Crushing Silver Skewer   3.37
# 1   21   Male      119  Stormbringer, Dark Blade of Ending Misery   2.32
# 2   34   Male      174                            Primitive Blade   2.46
# 3   21   Male       92                               Final Critic   1.36
# 4   23   Male       63                             Stormfury Mace   1.27
#
#              SN
# 0     Aelalis34
# 1        Eolo46
# 2   Assastnya25
# 3  Pheusrical25
# 4        Aela59

# %%
#PLAYER COUNT
player_total= gaming_data_df['SN'].nunique()
player_total
# Out:
# 573

# %%
#PURCHASE ANALYSIS
#unique items
gaming_data_df['Item Name'].nunique()
# Out:
# 179

# %%
#avg purch price
gaming_data_df['Price'].mean()
# Out:
# 2.931192307692303

# %%
#number of purchases
total_df = len(gaming_data_df)
total_df
# Out:
# 780

# %%
#total revenue
total_rev= gaming_data_df["Price"].sum()
total_rev
# Out:
# 2286.3299999999963

# %%
#GENDER ANALYSIS
#percent and count of Females
gaming_data_df['Gender'].value_counts()
# Out:
# Male                     633
# Female                   136
# Other / Non-Disclosed     11
# Name: Gender, dtype: int64

# %%
gaming_data_df['Gender'].value_counts("gender")
# Out:
# Male                     0.811538
# Female                   0.174359
# Other / Non-Disclosed    0.014103
# Name: Gender, dtype: float64

# %%
#PURCHASE ANALYSIS - FEMALE
gender_df= gaming_data_df.groupby(by="Gender")
gender_df.head()

gender_df = gaming_data_df.set_index("Gender")
female_df= gender_df.loc[["Female"],:]
female_df
# Out:
#         Age  Item ID                                  Item Name  Price  \
# Gender
# Female   29      169     Interrogator, Blood Blade of the Queen   3.32
# Female   22      123                          Twilight's Carver   1.14
# Female   22       59              Lightning, Etcher of the King   1.65
# Female   11       11                                  Brimstone   2.52
# Female   16       45                        Glinting Glass Edge   2.46
# Female   21      155                  War-Forged Gold Deflector   3.73
# Female   21       13                                   Serenity   1.49
# Female   19      124                             Venom Claymore   2.72
# Female   32       32                                    Orenmir   4.95
# Female   25      101                               Final Critic   4.62
# Female   24       65                  Conqueror Adamantite Mace   1.96
# Female   19       39       Betrayal, Whisper of Grieving Widows   2.35
# ...

# %%
#FEMALE PURCHASE COUNT
len(female_df)
# Out:
# 136

# %%
#FEMALE AVG PURCHASE COUNT
female_df['Price'].mean()
# Out:
# 2.815514705882352

# %%
#FEMALE TOTAL PURCH
female_df['Price'].sum()
# Out:
# 382.90999999999985

# %%
#NORMALIZED TOTALS
#female_df.div(female_df.sum(axis=1), axis=0)

# %%
#PURCHASE ANALYSIS - MALE
male_df= gender_df.loc[["Male"],:]
male_df
# Out:
#         Age  Item ID                                  Item Name  Price  \
# Gender
# Male     38      165                Bone Crushing Silver Skewer   3.37
# Male     21      119  Stormbringer, Dark Blade of Ending Misery   2.32
# Male     34      174                            Primitive Blade   2.46
# Male     21       92                               Final Critic   1.36
# Male     23       63                             Stormfury Mace   1.27
# Male     20       10                                Sleepwalker   1.73
# Male     20      153                            Mercenary Sabre   4.57
# Male     25      118           Ghost Reaver, Longsword of Magic   2.77
# Male     31       99       Expiration, Warscythe Of Lost Worlds   4.53
# Male     24       57            Despair, Favor of Due Diligence   3.81
# Male     20       47                Alpha, Reach of Ending Hope   1.55
# Male     30       81                                  Dreamkiss   4.06
# ...

# %%
#MALE PURCHASE COUNT
len(male_df)
# Out:
# 633

# %%
#MALE AVG PURCHASE COUNT
male_df['Price'].mean()
# Out:
# 2.9505213270142154

# %%
#MALE TOTAL PURCH
male_df['Price'].sum()
# Out:
# 1867.6799999999985

# %%
#AGE DEMOGRAPHICS
#binnning age
age_bins = [0, 10, 15, 20, 25, 30, 35, 40, 45, 50, 55, 60]
bin_names = ['0-10','10-14', '15-19', '20-24', '25-29','30-34', '35-39', '40-44', '45-49', '50-54', '55-60']

# %%
#AGE PURCH COUNT
#bin_df = pd.cut(gaming_data_df["Age"], age_bins, labels=bin_names)
#pd.cut.len((gaming_data_df["Age"]), age_bins, labels=bin_names)

bin_df = gaming_data_df.groupby(['age_bins', pd.cut (gaming_data_d.views, bin_names])

# %%
age_demo= gaming_data_df["Age"]= pd.cut(gaming_data_df["Price"], age_bins, labels=bin_names)

age_demo

# %% [markdown]
# #TOP SPENDERS
# gaming_data_df.sort_values("SN", ascending=False)

# %%
#AGE AVG PRICE
age_price_df = gaming_data_df.groupby("Age")['Price'].sum
#age_price_df["Price"].mean()
Print (age_price_df)
# Out:
# SN
# Adairialis76        2.46
# Aduephos78          6.70
# Aeduera68           5.80
# Aela49              2.46
# Aela59              1.27
# Aelalis34           5.06
# Aelin32             3.14
# Aeliriam77          6.72
# Aeliriarin93        2.04
# Aeliru63            8.98
# Aellyria80          4.32
# Aellyrialis39       3.15
# Aellysup38          3.61
# Aelollo59           1.55
# Aenarap34           1.65
# Aenasu69            3.27
# Aeral43             2.72
# Aeral85             4.25
# Aeral97             2.35
# Aeri84              6.60
# Aerillorin70        1.88
# Aerithllora36      10.45
# Aerithnucal56       3.18
# Aerithnuphos61      1.69
# Aerithriaphos45     2.38
# Aesty51             1.82
# Aesur96             4.66
# Aethe80             2.32
# Aethedru70          2.97
# Aidain51            6.84
#                    ...
# Undjaskla97         4.57
# Undjasksya56        4.53
# Undotesta33         3.90
# Wailin72            2.04
# Whaestysu86         4.08
# ...

# %%
#AGE TOTAL PURCH
age_price_df["Price"].sum()

# %%
#TOP 5 SPENDERS
#Item Name

top_spend_df = gaming_data_df.groupby("Item Name")['Price'].sum()
amt_price_df = gaming_data_df.groupby("Item Name")['Price'].count()
avg_price_df = gaming_data_df.groupby("Item Name")['Price'].mean()


print (top_spend_df)
print (amt_price_df)
print (avg_price_df)


#top_spend_df.sort_values("SN", ascending=False)

#gaming_data_df.sort_values("Item Name", ascending=False)
# Out:
# Item Name
# Abyssal Shard                                6.12
# Aetherius, Boon of the Blessed              19.00
# Agatha                                       9.55
# Alpha                                       10.92
# Alpha, Oath of Zeal                         20.16
# Alpha, Reach of Ending Hope                  9.30
# Amnesia                                     21.42
# Apocalyptic Battlescythe                    15.64
# Arcane Gem                                  24.53
# Avenger                                     24.96
# Azurewrath                                  11.10
# Betrayal, Whisper of Grieving Widows        25.85
# Betrayer                                     5.01
# Blade of the Grave                          11.83
# Blazefury, Protector of Delusions            3.00
# Blazeguard, Reach of Eternity               24.00
# Blindscythe                                 18.30
# Blood Infused Guardian                      14.30
# Blood-Forged Skeletal Spine                  9.54
# ...

# %%
top_spend_df.sort_values('Price', ascending=False)

#gaming_data_df.sort_values("Item Name", ascending=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-496-63ec85fe3198> in <module>()
# ----> 1 top_spend_df.sort_values('Price', ascending=False)
#       2
#       3 #gaming_data_df.sort_values("Item Name", ascending=False)
#
# ~\Anaconda3\envs\pydata\lib\site-packages\pandas\core\series.py in sort_values(self, axis, ascending, inplace, kind, na_position)
#    1683
#    1684         inplace = validate_bool_kwarg(inplace, 'inplace')
# -> 1685         axis = self._get_axis_number(axis)
#    1686
#    1687         # GH 5856/5853
#
# ~\Anaconda3\envs\pydata\lib\site-packages\pandas\core\generic.py in _get_axis_number(self, axis)
#     351                 pass
#     352         raise ValueError('No axis named {0} for object type {1}'
# --> 353                          .format(axis, type(self)))
#     354
#     355     def _get_axis_name(self, axis):
#
# ...

# %%
top_ID_df = gaming_data_df.groupby("Item ID")['Price'].sum()
amt_ID_df = gaming_data_df.groupby("Item ID")['Item Name'].count()
avg_ID_df = gaming_data_df.groupby("Item ID")['Price'].mean()

# %%
#gaming_data_df = gaming_data_df.set_index("")

# %%
SN_df = gaming_data_df.groupby("SN")



SN_df["SN"].value_counts()
SN_df["SN"].nunique().count()
 
print (SN_df)

# %%
total_value = gaming_data_df.groupby("Item Name")

# %%
total_value.count()
total_value["Price"].max()
total_value.mean()
total_value.head()
# Out:
#      Age                 Gender  Item ID  \
# 0     38                   Male      165
# 1     21                   Male      119
# 2     34                   Male      174
# 3     21                   Male       92
# 4     23                   Male       63
# 5     20                   Male       10
# 6     20                   Male      153
# 7     29                 Female      169
# 8     25                   Male      118
# 9     31                   Male       99
# 10    24                   Male       57
# 11    20                   Male       47
# 12    30                   Male       81
# 13    23                   Male       77
# 14    40                   Male       44
# 15    21                   Male       96
# 16    22                 Female      123
# 17    22                 Female       59
# 18    28                   Male       91
# 19    31                   Male      177
# 20    24                   Male       78
# 21    15                   Male        3
# ...

# %%
#OBSERVABLE TRENDS
#1) There are way more male gamers in the industry
#2)
